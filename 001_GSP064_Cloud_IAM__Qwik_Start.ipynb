# %% [markdown]
# [Cloud IAM: Qwik Start](https://www.cloudskillsboost.google/focuses/44159?parent=catalog)

# %% [markdown]
# ![2023-04-24 17_21_11-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_32_02-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_33_39-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_37_52-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_39_16-Uprawnienia – Administracja – qwiklabs-gcp-02-fb3… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_39_42-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_43_24-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# exam-685858

# %% [markdown]
# ![2023-04-24 17_46_07-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_47_57-exam-685858 – Szczegóły zasobnika – Cloud Storage – qwiklabs-gcp-02-fb3… – Googl.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_48_19-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_49_53-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_51_15-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_53_31-Uprawnienia – Administracja – qwiklabs-gcp-02-fb3… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_56_40-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/iam/docs/faq

# %% [markdown]
# ![2023-04-24 17_57_12-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_58_11-Error – Witamy – Qwiklabs Resources – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_59_03-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 17_59_16-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 18_01_00-Uprawnienia – Administracja – qwiklabs-gcp-02-fb3… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 18_01_34-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gsutil ls gs://exam-685858

# %% [markdown]
# ![2023-04-24 18_04_19-Error – Witamy – Qwiklabs Resources – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-24 18_04_56-Cloud IAM_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)
