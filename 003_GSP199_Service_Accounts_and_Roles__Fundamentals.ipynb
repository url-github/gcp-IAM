# %% [markdown]
# [Service Accounts and Roles: Fundamentals](https://www.cloudskillsboost.google/focuses/1038?parent=catalog)

# %% [markdown]
# ![2023-05-02 19_21_14-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-02 19_28_58-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://www.cloudskillsboost.google/focuses/964?parent=catalog
# https://www.cloudskillsboost.google/focuses/867?parent=catalog
# https://www.cloudskillsboost.google/focuses/59362?parent=catalog

# %% [markdown]
# ![2023-05-02 19_31_44-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/compute/docs/instances/
# https://developers.google.com/identity/protocols/oauth2/service-account?hl=pl#python

# %% [markdown]
# ![2023-05-02 19_40_06-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
PROJECT_NUMBER-compute@developer.gserviceaccount.com

# %% [markdown]
# ![2023-05-02 19_41_20-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
PROJECT_ID@appspot.gserviceaccount.com

# %% [markdown]
# ![2023-05-02 19_42_26-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
PROJECT_NUMBER@cloudservices.gserviceaccount.com

# %% [markdown]
# ![2023-05-02 19_42_43-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 09_37_45-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud iam service-accounts create my-sa-123 --display-name "my service account"

# %% [markdown]
# ![2023-05-03 09_43_34-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_23_31-Role – Administracja – qwiklabs-gcp-00-c00… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_24_49-Konta usługi – Administracja – qwiklabs-gcp-00-c00… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 09_44_24-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 09_46_31-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/iam/docs/overview#resource

# https://cloud.google.com/iam/docs/overview#concepts_related_to_identity

# https://cloud.google.com/iam/docs/service-account-overview#the_service_account_user_role

# %% [markdown]
# ![2023-05-03 10_04_42-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud projects add-iam-policy-binding $DEVSHELL_PROJECT_ID \
    --member serviceAccount:my-sa-123@$DEVSHELL_PROJECT_ID.iam.gserviceaccount.com --role roles/editor

# %% [markdown]
# ![2023-05-03 10_27_05-Konta usługi – Administracja – qwiklabs-gcp-00-c00… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_08_17-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/iam/docs/understanding-roles

# %% [markdown]
# ![2023-05-03 10_21_36-Service Accounts and Roles_ Fundamentals _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_35_14-Utworzenie konta usługi – Administracja – qwiklabs-gcp-00-c00… – Google Cloud Co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_36_38-Konta usługi – Administracja – qwiklabs-gcp-00-c00… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_35_42-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_39_56-Compute Engine – qwiklabs-gcp-00-c00… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_40_30-Compute Engine – qwiklabs-gcp-00-c00… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_41_32-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
sudo apt-get update

# %%
sudo apt-get install -y git python3-pip

# %%
pip3 install --upgrade pip

# %%
pip3 install google-cloud-bigquery

# %%
pip3 install pyarrow

# %%
pip3 install pandas

# %%
pip3 install db-dtypes

# %% [markdown]
# ![2023-05-03 10_47_16-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
echo "
from google.auth import compute_engine
from google.cloud import bigquery
credentials = compute_engine.Credentials(
    service_account_email='YOUR_SERVICE_ACCOUNT')
query = '''
SELECT
  year,
  COUNT(1) as num_babies
FROM
  publicdata.samples.natality
WHERE
  year > 2000
GROUP BY
  year
'''
client = bigquery.Client(
    project='YOUR_PROJECT_ID',
    credentials=credentials)
print(client.query(query).to_dataframe())
" > query.py

# %%
sed -i -e "s/YOUR_PROJECT_ID/$(gcloud config get-value project)/g" query.py

# %% [markdown]
# ![2023-05-03 10_52_42-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cat query.py

# %% [markdown]
# ![2023-05-03 10_53_45-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
sed -i -e "s/YOUR_SERVICE_ACCOUNT/bigquery-qwiklab@$(gcloud config get-value project).iam.gserviceaccount.com/g" query.py

# %%
cat query.py

# %% [markdown]
# ![2023-05-03 10_56_16-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
python3 query.py

# %% [markdown]
# ![2023-05-03 10_57_44-https___ssh.cloud.google.com_v2_ssh_projects_qwiklabs-gcp-00-c00249aeb16f_zones_.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 10_58_37-Konta usług i role_ podstawy _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)
